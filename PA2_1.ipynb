# %%
# Import libraries
import pandas as pd
import altair as alt
import csv

# %%
# Data retrieved from https://www.kaggle.com/crawford/80-cereals?select=cereal.csv
# Read the data and put it in a panda's dataframe

attributes = []
records = []
with open('cereal.csv') as inFile:
    reader = csv.reader(inFile)
    for row in reader:
        if (row[0] == "name"):
            attributes = row
            continue
        records.append(row)

df = pd.DataFrame(records, columns = attributes)
df
# Out:
#                          name mfr type calories protein fat sodium fiber  \
# 0                   100% Bran   N    C       70       4   1    130    10
# 1           100% Natural Bran   Q    C      120       3   5     15     2
# 2                    All-Bran   K    C       70       4   1    260     9
# 3   All-Bran with Extra Fiber   K    C       50       4   0    140    14
# 4              Almond Delight   R    C      110       2   2    200     1
# ..                        ...  ..  ...      ...     ...  ..    ...   ...
# 72                    Triples   G    C      110       2   1    250     0
# 73                       Trix   G    C      110       1   1    140     0
# 74                 Wheat Chex   R    C      100       3   1    230     3
# 75                   Wheaties   G    C      100       3   1    200     3
# 76        Wheaties Honey Gold   G    C      110       2   1    200     1
#
#    carbo sugars potass vitamins shelf weight  cups     rating
# ...

# %%
PAD = 20

# %%
scatterPlot =alt.Chart(df).mark_point(size=20).encode(
    x=alt.X('carbo:Q', 
        sort=alt.EncodingSortField('carbo', order='descending'), 
        axis=alt.Axis(title='Carbohydrates (g)')
    ),
    y=alt.Y('calories:Q',
        sort=alt.EncodingSortField('calories', order='descending'), 
        axis=alt.Axis(title='Calories')
    )
).properties(
    title='The Affect of Carbohydrates on Calories',
    width=300,
    height=220
)

scatterPlot + scatterPlot.transform_regression('carbo', 'calories', 
    extent=[-10,25] ,
    method="linear"
).mark_line(color="red")
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(df).mark_circle().encode(
    x = alt.X('calories:Q', 
        axis=alt.Axis(title='Calories'),
        bin=True),
    y = alt.Y('rating:Q', 
        axis=alt.Axis(title='Rating'),
        bin=True),
    size='count()'
).properties(
    title='The Affect of Calories on Ratings (Binned)',
    width=300,
    height=220
).configure(
    padding={"left": PAD, "top": PAD, "right": PAD, "bottom": PAD}
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_boxplot().encode(
    x = alt.X('mfr:O', 
        axis=alt.Axis(title='Manufacturer')),
    y = alt.Y('rating:Q', 
        axis=alt.Axis(title='Rating'))
).properties(
    title='A Comparison of Each Manufacturer\'s Ratings',
    width=300,
    height=220
).configure(
    padding={"left": PAD, "top": PAD, "right": PAD+20, "bottom": PAD}
)
# Out:
# alt.Chart(...)
